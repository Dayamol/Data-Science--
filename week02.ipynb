# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Download the two files and load them into pandas data frames. Hint: have a look at this page and do not forget to parse your excel sheet into a data frame.
# Merge the two files based on the column they share.
# Display the name of the oldest passengers (hint: make use of variables to save some intermediate values).
# Plot the data on a scatter plot that shows the Age vs. Ticket Prices
# Plot only the data that shows female passengers aged 40 to 50 and who paid more than or equal to 40.

# %%
df1=pd.read_csv(r"C:\Users\dayam\OneDrive\Desktop\prici data sci\passengerData.csv")
df2=pd.read_excel(r"C:\Users\dayam\OneDrive\Desktop\prici data sci\ticketPrices.xlsx")

# %%
df1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  TicketType
# 0                            Braund, Mr. Owen Harris    male  22.0           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0           2
# 2                             Heikkinen, Miss. Laina  female  26.0           3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0           4
# 4                           Allen, Mr. William Henry    male  35.0           5
# 5                                   Moran, Mr. James    male   NaN           6
# 6                            McCarthy, Mr. Timothy J    male  54.0           7
# 7                     Palsson, Master. Gosta Leonard    male   2.0           8
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0           1
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0           2

# %%
df2.head(10)
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
df=pd.merge(df1,df2,on='TicketType')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            9         1       3
# 2           17         0       3
# 3           25         0       3
# 4           33         1       3
# 5           41         0       3
# 6           49         0       3
# 7           57         1       2
# 8           65         0       1
# 9           73         0       2
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                               Rice, Master. Eugene    male   2.0
# 3                      Palsson, Miss. Torborg Danira  female   8.0
# 4                           Glynn, Miss. Mary Agatha  female   NaN
# 5     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 6                                Samaan, Mr. Youssef    male   NaN
# 7                                  Rugg, Miss. Emily  female  21.0
# 8                              Stewart, Mr. Albert A    male   NaN
# 9                               Hood, Mr. Ambrose Jr    male  21.0
#
#    TicketType  Fare
# 0           1    33
# 1           1    33
# 2           1    33
# 3           1    33
# 4           1    33
# 5           1    33
# 6           1    33
# 7           1    33
# 8           1    33
# 9           1    33

# %%
oldpass=df['Age'].max()
oldpass
# Out:
# 80.0

# %%
oldie=df.query('Age==80.0')['Name']
oldie
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.plot(kind='scatter', x='Age', y='Fare', figsize=(10, 6), color='darkblue')

plt.title('Age of the passengers')
plt.xlabel('Fare')
plt.ylabel('Age vs Fare')

plt.show()

# %%
dff=df.loc[(df['Age']>=40) & (df['Age']<=60) & (df['Fare']>=40)&(df['Sex']=='female')]
dff
# Out:
#      PassengerId  Survived  Pclass  \
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 176          514         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 653          766         1       1
# 700          255         0       3
# 714          367         1       1
# 734          527         1       2
# 748          639         0       3
# 752          671         1       2
# 753          679         0       3
# 765          775         1       2
# 775          855         0       2
# 776          863         1       1
#
#                                                   Name     Sex   Age  \
# 132  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0
# 134                         Isham, Miss. Ann Elizabeth  female  50.0
# 154                    Burns, Miss. Elizabeth Margaret  female  41.0
# 176     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0
# 188                          Shutes, Miss. Elizabeth W  female  40.0
# 220                           Bystrom, Mrs. (Karolina)  female  42.0
# 248          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0
# 267                          Smith, Miss. Marion Elsie  female  40.0
# 269                    Barbara, Mrs. (Catherine David)  female  45.0
# 281                                Toomey, Miss. Ellen  female  50.0
# 312                      Kelly, Mrs. Florence "Fannie"  female  45.0
# 318                   Herman, Mrs. Samuel (Jane Laver)  female  48.0
# 653               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0
# 700           Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.0
# 714   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0
# 734                               Ridsdale, Miss. Lucy  female  50.0
# 748             Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0
# 752  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0
# 753            Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0
# 765              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0
# 775      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0
# 776  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
#
#      TicketType  Fare
# 132           2    56
# 134           2    56
# 154           2    56
# 176           2    56
# 188           2    56
# 220           2    56
# 248           3    77
# 267           3    77
# 269           3    77
# 281           3    77
# 312           3    77
# 318           3    77
# 653           6    66
# 700           7    87
# 714           7    87
# 734           7    87
# 748           7    87
# 752           7    87
# 753           7    87
# 765           7    87
# 775           7    87
# 776           7    87

# %% [markdown]
# Load the slightly modified Titanic survival data  into a pandas data frame.
# Find the counts of missing values in each column
# Compute the mean and other descriptive statistics and note these down, you can use this function
# Replace the missing values in "Age" and "Fare" columns with 0 values, and visualise in a scatterplot
# Replace the missing values in "Age" and "Fare" columns with the mean of each column, and visualise in a scatterplot
# Reflect on the differences you see in these plots.

# %%
tt=pd.read_csv(r"C:\Users\dayam\OneDrive\Desktop\prici data sci\titanicSurvival_m.csv")
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
missing_data = tt.isnull()
missing_data.head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# PassengerId
# False    891
# Name: PassengerId, dtype: int64
#
# Survived
# False    891
# Name: Survived, dtype: int64
#
# Pclass
# False    891
# Name: Pclass, dtype: int64
#
# Name
# False    891
# Name: Name, dtype: int64
#
# Sex
# False    891
# Name: Sex, dtype: int64
#
# Age
# False    714
# True     177
# Name: Age, dtype: int64
#
# SibSp
# False    891
# Name: SibSp, dtype: int64
#
# Parch
# False    891
# Name: Parch, dtype: int64
#
# Ticket
# False    891
# Name: Ticket, dtype: int64
#
# Fare
# False    845
# True      46
# Name: Fare, dtype: int64
#
# Cabin
# True     687
# False    204
# Name: Cabin, dtype: int64
#
# Embarked
# False    889
# True       2
# Name: Embarked, dtype: int64

# %%
tt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  845.000000
# mean     0.381594   32.304319
# std      0.806057   49.792612
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
df3 = tt['Age']

# %%
print(df3.isnull().values.sum() != 0)
# Out:
# True

# %%
tt['Age'] = tt['Age'].fillna(0)

# %%
missing_data1 = df3.notnull()
missing_data1.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Age, dtype: bool

# %%
print(df3.isnull().values.sum() != 0)
print(df3.size)
print(df3.isnull().values.sum() == df.size)
# Out:
# False
# 891
# False

# %%
tt['Fare'] = tt['Fare'].fillna(0)

# %%
print(df4.isnull().values.sum() != 0)
print(df4.size)
print(df4.isnull().values.sum() == df.size)
# Out:
# False
# 891
# False

# %%
missing_data = tt.isnull()
missing_data.head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# PassengerId
# False    891
# Name: PassengerId, dtype: int64
#
# Survived
# False    891
# Name: Survived, dtype: int64
#
# Pclass
# False    891
# Name: Pclass, dtype: int64
#
# Name
# False    891
# Name: Name, dtype: int64
#
# Sex
# False    891
# Name: Sex, dtype: int64
#
# Age
# False    891
# Name: Age, dtype: int64
#
# SibSp
# False    891
# Name: SibSp, dtype: int64
#
# Parch
# False    891
# Name: Parch, dtype: int64
#
# Ticket
# False    891
# Name: Ticket, dtype: int64
#
# Fare
# False    891
# Name: Fare, dtype: int64
#
# Cabin
# True     687
# False    204
# Name: Cabin, dtype: int64
#
# Embarked
# False    889
# True       2
# Name: Embarked, dtype: int64

# %%
tt.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742   0.0000   NaN        S
# 9      0            237736   0.0000   NaN        C

# %%
tt.plot.scatter(['Age'], ['Fare'])

# %%
meanA = tt['Age'].astype("float").mean(axis=0)
meanF = tt['Fare'].astype("float").mean(axis=0)
print(meanA)
print(meanF)
# Out:
# 23.79929292929293
# 30.636531313131275

# %%
tt['Age'].replace(0, meanA, inplace=False)
tt['Fare'].replace(0, meanF, inplace=False)
tt.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742   0.0000   NaN        S
# 9      0            237736   0.0000   NaN        C

# %%
tt.plot.scatter(['Age'], ['Fare'])

# %% [markdown]
# Download the csv data file from WHO on Tuberculosis (from Week01)  . Information on the data can be found on WHO's web page.
# You may need to replace missing values before you start.
# Choose a number of columns with different shapes, for instance, "e_prev_100k_hi" is right skewed and visualise on an histogram
# Apply a log transformation on the data. Numpy has a log function. and visualise. Observe the changes
# Choose the numerical columns and map all the columns to [0,1] interval
# Now you can compare the means of each column.

# %%
who=pd.read_csv(r"C:\Users\dayam\OneDrive\Desktop\prici data sci\TB_burden_countries_2014-09-29.csv")
who.head(10)
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0  Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1  Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2  Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3  Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4  Afghanistan   AF  AFG            4         EMR  1994   16485018
# 5  Afghanistan   AF  AFG            4         EMR  1995   17586073
# 6  Afghanistan   AF  AFG            4         EMR  1996   18415307
# 7  Afghanistan   AF  AFG            4         EMR  1997   19021226
# 8  Afghanistan   AF  AFG            4         EMR  1998   19496836
# 9  Afghanistan   AF  AFG            4         EMR  1999   19987071
#
#    e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# 0        327.0           112.0           655.0  ...              0.35
# 1        359.0           172.0           613.0  ...              0.36
# 2        387.0           169.0           693.0  ...              0.37
# 3        412.0           186.0           724.0  ...              0.38
# 4        431.0           199.0           751.0  ...              0.40
# 5        447.0           208.0           775.0  ...              0.41
# 6        461.0           211.0           806.0  ...              0.43
# 7        469.0           211.0           827.0  ...              0.44
# 8        474.0           213.0           837.0  ...              0.46
# 9        465.0           211.0           817.0  ...              0.48
#
#    e_inc_tbhiv_100k_lo  e_inc_tbhiv_100k_hi  e_inc_tbhiv_num  \
# 0                 0.22                 0.52             41.0
# 1                 0.19                 0.58             45.0
# 2                 0.19                 0.62             51.0
# 3                 0.20                 0.63             58.0
# 4                 0.21                 0.64             65.0
# 5                 0.23                 0.65             72.0
# 6                 0.24                 0.67             78.0
# 7                 0.25                 0.69             84.0
# 8                 0.26                 0.72             89.0
# 9                 0.27                 0.75             96.0
#
#    e_inc_tbhiv_num_lo  e_inc_tbhiv_num_hi  source_tbhiv  c_cdr  c_cdr_lo  \
# 0                25.0                60.0         Model   20.0      13.0
# 1                24.0                73.0         Model   97.0      77.0
# 2                26.0                86.0         Model    NaN       NaN
# 3                30.0                95.0         Model    NaN       NaN
# 4                35.0               100.0         Model    NaN       NaN
# 5                40.0               110.0         Model    NaN       NaN
# 6                44.0               120.0         Model    NaN       NaN
# 7                47.0               130.0         Model    3.6       3.0
# 8                50.0               140.0         Model    8.4       7.0
# 9                54.0               150.0         Model    8.8       7.3
#
#   c_cdr_hi
# 0     32.0
# 1    120.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      4.4
# 8     10.0
# 9     11.0
#
# [10 rows x 39 columns]

# %%
missing_data1 = who.isnull()
missing_data1.head()
# Out:
#    country   iso2   iso3  iso_numeric  g_whoregion   year  e_pop_num  \
# 0    False  False  False        False        False  False      False
# 1    False  False  False        False        False  False      False
# 2    False  False  False        False        False  False      False
# 3    False  False  False        False        False  False      False
# 4    False  False  False        False        False  False      False
#
#    e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# 0        False           False           False  ...             False
# 1        False           False           False  ...             False
# 2        False           False           False  ...             False
# 3        False           False           False  ...             False
# 4        False           False           False  ...             False
#
#    e_inc_tbhiv_100k_lo  e_inc_tbhiv_100k_hi  e_inc_tbhiv_num  \
# 0                False                False            False
# 1                False                False            False
# 2                False                False            False
# 3                False                False            False
# 4                False                False            False
#
#    e_inc_tbhiv_num_lo  e_inc_tbhiv_num_hi  source_tbhiv  c_cdr  c_cdr_lo  \
# 0               False               False         False  False     False
# 1               False               False         False  False     False
# 2               False               False         False   True      True
# 3               False               False         False   True      True
# 4               False               False         False   True      True
#
#    c_cdr_hi
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
#
# [5 rows x 39 columns]

# %%
for column in missing_data1.columns.values.tolist():
    print(column)
    print (missing_data1[column].value_counts())
    print("")
# Out:
# country
# False    4903
# Name: country, dtype: int64
#
# iso2
# False    4880
# True       23
# Name: iso2, dtype: int64
#
# iso3
# False    4903
# Name: iso3, dtype: int64
#
# iso_numeric
# False    4903
# Name: iso_numeric, dtype: int64
#
# g_whoregion
# False    4903
# Name: g_whoregion, dtype: int64
#
# year
# False    4903
# Name: year, dtype: int64
#
# e_pop_num
# False    4903
# Name: e_pop_num, dtype: int64
#
# e_prev_100k
# False    4892
# True       11
# Name: e_prev_100k, dtype: int64
#
# e_prev_100k_lo
# False    4892
# True       11
# Name: e_prev_100k_lo, dtype: int64
#
# e_prev_100k_hi
# False    4892
# True       11
# Name: e_prev_100k_hi, dtype: int64
#
# e_prev_num
# False    4892
# True       11
# Name: e_prev_num, dtype: int64
#
# e_prev_num_lo
# False    4892
# True       11
# Name: e_prev_num_lo, dtype: int64
#
# e_prev_num_hi
# False    4892
# True       11
# Name: e_prev_num_hi, dtype: int64
#
# e_mort_exc_tbhiv_100k
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_100k, dtype: int64
#
# e_mort_exc_tbhiv_100k_lo
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_100k_lo, dtype: int64
#
# e_mort_exc_tbhiv_100k_hi
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_100k_hi, dtype: int64
#
# e_mort_exc_tbhiv_num
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_num, dtype: int64
#
# e_mort_exc_tbhiv_num_lo
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_num_lo, dtype: int64
#
# e_mort_exc_tbhiv_num_hi
# False    4902
# True        1
# Name: e_mort_exc_tbhiv_num_hi, dtype: int64
#
# source_mort
# False    4902
# True        1
# Name: source_mort, dtype: int64
#
# e_inc_100k
# False    4902
# True        1
# Name: e_inc_100k, dtype: int64
#
# e_inc_100k_lo
# False    4902
# True        1
# Name: e_inc_100k_lo, dtype: int64
#
# e_inc_100k_hi
# False    4902
# True        1
# Name: e_inc_100k_hi, dtype: int64
#
# e_inc_num
# False    4902
# True        1
# Name: e_inc_num, dtype: int64
#
# e_inc_num_lo
# False    4902
# True        1
# Name: e_inc_num_lo, dtype: int64
#
# e_inc_num_hi
# False    4902
# True        1
# Name: e_inc_num_hi, dtype: int64
#
# e_tbhiv_prct
# False    3653
# True     1250
# Name: e_tbhiv_prct, dtype: int64
#
# e_tbhiv_prct_lo
# False    3457
# True     1446
# Name: e_tbhiv_prct_lo, dtype: int64
#
# e_tbhiv_prct_hi
# False    3457
# True     1446
# Name: e_tbhiv_prct_hi, dtype: int64
#
# e_inc_tbhiv_100k
# False    3597
# True     1306
# Name: e_inc_tbhiv_100k, dtype: int64
#
# e_inc_tbhiv_100k_lo
# False    3597
# True     1306
# Name: e_inc_tbhiv_100k_lo, dtype: int64
#
# e_inc_tbhiv_100k_hi
# False    3597
# True     1306
# Name: e_inc_tbhiv_100k_hi, dtype: int64
#
# e_inc_tbhiv_num
# False    3597
# True     1306
# Name: e_inc_tbhiv_num, dtype: int64
#
# e_inc_tbhiv_num_lo
# False    3597
# True     1306
# Name: e_inc_tbhiv_num_lo, dtype: int64
#
# e_inc_tbhiv_num_hi
# False    3597
# True     1306
# Name: e_inc_tbhiv_num_hi, dtype: int64
#
# source_tbhiv
# False    4902
# True        1
# Name: source_tbhiv, dtype: int64
#
# c_cdr
# False    4476
# True      427
# Name: c_cdr, dtype: int64
#
# c_cdr_lo
# False    4476
# True      427
# Name: c_cdr_lo, dtype: int64
#
# c_cdr_hi
# False    4476
# True      427
# Name: c_cdr_hi, dtype: int64
